# %%
# import csv file 
from pathlib import Path
import csv

csvpath = Path('/Users/joemazzuca/Desktop/UofT_FinTech_Boot_Camp/Week_2/Homework_Assignment/python-homework/PyBank/budget_data.csv')

# create analysis dictionary
analysis = {} 

with open(csvpath, 'r') as csvfile:
    csvreader = csv.reader(csvfile, delimiter = ',')
    
    # populate csv data into analysis dictionary
    for row in csvreader:
        analysis[row[0]] = row[1]

# remove header from csv file in dictionary
del analysis['Date'] 

# initialize metric variables
total_pnl = 0

number_of_months = 0

pnl_list = []

max_value = 0
max_date = ""

min_value = 0
min_date = ""

# iterate over key-value pairs in dictionary
for date, pnl in analysis.items():
    # calculate total profit/loss and sum the total number of months for the period
    profit_loss = int(pnl)
    
    total_pnl += profit_loss
    number_of_months += 1
    
    # add items to pnl_list
    pnl_list.append(profit_loss)
        
    # determine minimum key and value as well as the maximum key and maximum value
    if min_value == 0:
        min_value = profit_loss
        min_date = date
    elif min_value > profit_loss:
        min_value = profit_loss
        min_date = date
    elif max_value < profit_loss:
        max_value = profit_loss
        max_date = date

# solve month-to-month change in value and format in list
monthly_change = [pnl_list[i + 1] - pnl_list[i] for i in range(len(pnl_list) - 1)]

# initialize metric variable for monthly_change
monthly_change_sum = 0

# calculate sum of monthly_change list
for difference in monthly_change:
    monthly_change_sum += difference

# calculate average monthly change in profit/loss
avg_monthly_change = round(monthly_change_sum / len(monthly_change), 2)

# print out statistics
print("Financial Analysis")
print("----------------------------")
print(f"Total Months: {number_of_months}")
print(f"Total Profit/Loss: ${total_pnl}")
print(f"Average Change: ${avg_monthly_change}")
print(f"Greatest Increase in Profits: {max_date} (${max_value})")
print(f"Greatest Decrease in Profits: {min_date} (${min_value})")

# create text file to output statistics
output_path = 'pybank_results.txt'

with open (output_path, 'w') as file:
    file.write("Financial Analysis\n")
    file.write("----------------------------\n")
    file.write(f"Total Months: {number_of_months}\n")
    file.write(f"Total Profit/Loss: ${total_pnl}\n")
    file.write(f"Average Change: ${avg_monthly_change}\n")
    file.write(f"Greatest Increase in Profits: {max_date} (${max_value})\n")
    file.write(f"Greatest Decrease in Profits: {min_date} (${min_value})")
# Out:
# Financial Analysis
# ----------------------------
# Total Months: 86
# Total Profit/Loss: $38382578
# Average Change: $-2315.12
# Greatest Increase in Profits: Feb-2012 ($1170593)
# Greatest Decrease in Profits: Sep-2013 ($-1196225)
